# %% [markdown]
# <a href="https://colab.research.google.com/github/emily2925/Identify_Spotify_Loyal_Customer/blob/main/Identify_Spotify_Loyal_Customer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data_raw = pd.read_excel("/content/drive/MyDrive/Data_Scientist/Projects/Identify_Spotify_Loyal_Customer/spotify_data.xlsx")

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          520 non-null    object
#  1   Gender                       520 non-null    object
#  2   spotify_usage_period         520 non-null    object
#  3   spotify_listening_device     520 non-null    object
#  4   spotify_subscription_plan    520 non-null    object
#  5   premium_sub_willingness      520 non-null    object
#  6   preffered_premium_plan       312 non-null    object
#  7   preferred_listening_content  520 non-null    object
#  8   fav_music_genre              520 non-null    object
#  9   music_time_slot              520 non-null    object
#  10  music_Influencial_mood       520 non-null    object
#  11  music_lis_frequency          520 non-null    object
#  12  music_expl_method            520 non-null    object
# ...

# %%
data_raw.groupby("spotify_usage_period").count()
# Out:
#                       Age  Gender  spotify_listening_device  \
# spotify_usage_period
# 1 year to 2 years     141     141                       141
# 6 months to 1 year    119     119                       119
# Less than 6 months     91      91                        91
# More than 2 years     169     169                       169
#
#                       spotify_subscription_plan  premium_sub_willingness  \
# spotify_usage_period
# 1 year to 2 years                           141                      141
# 6 months to 1 year                          119                      119
# Less than 6 months                           91                       91
# More than 2 years                           169                      169
#
#                       preffered_premium_plan  preferred_listening_content  \
# spotify_usage_period
# 1 year to 2 years                         91                          141
# 6 months to 1 year                        83                          119
# ...

# %%
data_raw
# Out:
#        Age  Gender spotify_usage_period  \
# 0    20-35  Female    More than 2 years
# 1    12-20    Male    More than 2 years
# 2    35-60  Others   6 months to 1 year
# 3    20-35  Female    1 year to 2 years
# 4    20-35  Female    1 year to 2 years
# ..     ...     ...                  ...
# 515  20-35  Female    More than 2 years
# 516  20-35  Female    More than 2 years
# 517  20-35  Female    More than 2 years
# 518  20-35  Female   6 months to 1 year
# 519  20-35  Female    More than 2 years
#
#                              spotify_listening_device  \
# 0                  Smart speakers or voice assistants
# 1                                  Computer or laptop
# 2                  Smart speakers or voice assistants
# 3      Smartphone, Smart speakers or voice assistants
# 4                                          Smartphone
# ..                                                ...
# 515  Smartphone, Computer or laptop, Wearable devices
# ...

# %% [markdown]
# # Data Preprocess

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          520 non-null    object
#  1   Gender                       520 non-null    object
#  2   spotify_usage_period         520 non-null    object
#  3   spotify_listening_device     520 non-null    object
#  4   spotify_subscription_plan    520 non-null    object
#  5   premium_sub_willingness      520 non-null    object
#  6   preffered_premium_plan       312 non-null    object
#  7   preferred_listening_content  520 non-null    object
#  8   fav_music_genre              520 non-null    object
#  9   music_time_slot              520 non-null    object
#  10  music_Influencial_mood       520 non-null    object
#  11  music_lis_frequency          520 non-null    object
#  12  music_expl_method            520 non-null    object
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          520 non-null    string
#  1   Gender                       520 non-null    string
#  2   spotify_usage_period         520 non-null    string
#  3   spotify_listening_device     520 non-null    string
#  4   spotify_subscription_plan    520 non-null    string
#  5   premium_sub_willingness      520 non-null    string
#  6   preffered_premium_plan       520 non-null    string
#  7   preferred_listening_content  520 non-null    string
#  8   fav_music_genre              520 non-null    string
#  9   music_time_slot              520 non-null    string
#  10  music_Influencial_mood       520 non-null    string
#  11  music_lis_frequency          520 non-null    string
#  12  music_expl_method            520 non-null    string
# ...

# %%
df_clean = data_raw.copy()

# %%
# Missing Value
df_clean["preffered_premium_plan"] = df_clean["preffered_premium_plan"].fillna("No sub plan Rs 0/mopnth")
df_clean["fav_pod_genre"] = df_clean["fav_pod_genre"].fillna("Do not like podcast")
df_clean["preffered_pod_format"] = df_clean["preffered_pod_format"].fillna("Do not like podcast")
df_clean["pod_host_preference"] = df_clean["pod_host_preference"].fillna("Do not like podcast")
df_clean["preffered_pod_duration"] = df_clean["preffered_pod_duration"].fillna("Do not like podcast")

# %%
# Data Type correction
string_columns = ["Age", "Gender", "spotify_usage_period", "spotify_listening_device",
                  "spotify_subscription_plan", "premium_sub_willingness",
                  "preffered_premium_plan", "preferred_listening_content",
                  "fav_music_genre", "music_time_slot", "music_Influencial_mood",
                  "music_lis_frequency", "music_expl_method",
                  "pod_lis_frequency", "fav_pod_genre", "preffered_pod_format",
                  "pod_host_preference", "preffered_pod_duration", "pod_variety_satisfaction"]

for i in string_columns:
  df_clean[i] = df_clean[i].astype("string")
